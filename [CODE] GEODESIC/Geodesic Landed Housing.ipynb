# %%
import json
import requests
import pandas as pd
from geopy.distance import geodesic

# %%
def find_postal(lst, filename):
    
    for index,add in enumerate(lst):
        url= "https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal="+add
        print(index,url)
        response = requests.get(url)
        data = json.loads(response.text) 
        temp_df = pd.DataFrame.from_dict(data["results"])
        temp_df["address"] = add
    
        if index == 0:
            file = temp_df
            print(add,'Failed')
        else:
            file = file.append(temp_df)
    file.to_csv(filename + '.csv')

# %%
non_landed = pd.read_csv('Landed.csv', encoding='ISO-8859-1')
non_landed.head()
unique_address = non_landed['Street Name'].unique()

find_postal(unique_address, "Landed_geoloc_1")
# Out:
# 0 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=SERANGOON NORTH AVENUE 1
# SERANGOON NORTH AVENUE 1 Failed
# 1 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=BELGRAVIA DRIVE
# 2 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=CLUNY PARK ROAD
# 3 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=CASHEW ROAD
# 4 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=EAST COAST AVENUE
# 5 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=CHANCERY HILL ROAD
# 6 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=SURIN AVENUE
# 7 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=DYSON ROAD
# 8 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=TAN SIM BOH ROAD
# 9 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=BEDOK SOUTH AVENUE 3
# 10 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=WHAMPOA EAST
# 11 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=BALMORAL ROAD
# 12 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=RICHARDS AVENUE
# 13 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=LIM AH PIN ROAD
# 14 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=LORONG K TELOK KURAU
# 15 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=SOUTH BUONA VISTA ROAD
# 16 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=UPPER SERANGOON VIEW
# 17 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=ENG KONG ROAD
# 18 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=ENG KONG TERRACE
# 19 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=LORONG KISMIS
# 20 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=UPPER TOH TUCK TERRACE
# 21 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=FLOWER ROAD
# 22 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=GROVE DRIVE
# 23 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=GLASGOW ROAD
# 24 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=CLUNY HILL
# 25 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=SUNSHINE TERRACE
# 26 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=HOLLAND ROAD
# 27 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=VANDA AVENUE
# 28 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=CORONATION DRIVE
# 29 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=JALAN MELOR
# 30 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=JALAN CHENGKEK
# 31 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=DA SILVA LANE
# 32 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=GREENDALE RISE
# 33 https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal=JALAN LEMBAH THOMSON
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\CHENGA~1\AppData\Local\Temp/ipykernel_52096/595615446.py in <module>
#       3 unique_address = non_landed['Street Name'].unique()
#       4
# ----> 5 find_postal(unique_address, "Landed_geoloc_1")
#
# C:\Users\CHENGA~1\AppData\Local\Temp/ipykernel_52096/3502750268.py in find_postal(lst, filename)
#       4         url= "https://developers.onemap.sg/commonapi/search?returnGeom=Y&getAddrDetails=Y&pageNum=1&searchVal="+add
#       5         print(index,url)
# ----> 6         response = requests.get(url)
#       7         data = json.loads(response.text)
#       8         temp_df = pd.DataFrame.from_dict(data["results"])
#
# c:\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\python39\lib\http\client.py in getresponse(self)
#    1347         try:
#    1348             try:
# -> 1349                 response.begin()
#    1350             except ConnectionError:
#    1351                 self.close()
#
# c:\python39\lib\http\client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# c:\python39\lib\http\client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# c:\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
non_landed_postal = pd.read_csv('Landed_geoloc_1.csv')
non_landed_postal = non_landed_postal.drop_duplicates(subset=['address'], keep='first')
df_non_landed_postal= pd.merge(non_landed, non_landed_postal, how='left', left_on=['Street Name'], right_on=['address']).dropna()
df_non_landed_postal.to_csv('Landed_withpostal.csv')

# %%
def find_nearest(house, amenity):
    """
    this function finds the nearest locations from the 2nd table from the 1st address
    add_lat_lon_start, add_lat_lon_end --> both is a data frame with a specific format:
        1st column: any string column ie addresses, mrt stations
        2nd column: latitude (float)
        3rd column: longitude (float)
    Column name doesn't matter.
    """
    results = {}
    # first column must be address
    for index,flat in enumerate(house.iloc[:,0]):
        
        # 2nd column must be latitude, 3rd column must be longitude
        flat_loc = (house.iloc[index,1],house.iloc[index,2])
        flat_amenity = ['','',100]
        for ind, eachloc in enumerate(amenity.iloc[:,0]):
            
            amenity_loc = (amenity.iloc[ind,1],amenity.iloc[ind,2])

            distance = geodesic(flat_loc,amenity_loc)

            if distance < flat_amenity[2]:
                flat_amenity[0] = flat
                flat_amenity[1] = eachloc
                flat_amenity[2] = distance

        results[flat] = flat_amenity
    return results

# %%
# hdb resale dataset with location
geo = pd.read_csv("Landed_withpostal.csv")
geo1 = geo[['address', 'LATITUDE', 'LONGITUDE']]


data = [['cityhall', 1.29317576, 103.8525073]] 
sgcentre = pd.DataFrame(data, columns = ['address', 'LATITUDE', 'LONGITUDE'])
sgcentre
map_sgcentre = find_nearest(geo1,sgcentre)
map_sgcentre1 = pd.DataFrame(map_sgcentre)
map_sgcentre2 = map_sgcentre1.transpose()
map_sgcentre2.to_csv('city_NEW.csv',index = False)

supermarket = pd.read_csv("supermarket_geoloc.csv")
supermarket1 = supermarket[['Supermarket','LATITUDE', 'LONGITUDE']]
map_supermarket = find_nearest(geo1,supermarket1)
map_supermarket1 = pd.DataFrame(map_supermarket)
map_supermarket2 = map_supermarket1.transpose()
map_supermarket2.to_csv('supermarket_NEW.csv',index = False)

hawker_ = pd.read_csv("hawker_geoloc.csv")
hawker_1 = hawker_[['HAWKER','LATITUDE', 'LONGITUDE']]
map_hawker_ = find_nearest(geo1,hawker_1)
map_hawker_1 = pd.DataFrame(map_hawker_)
map_hawker_2 = map_hawker_1.transpose()
map_hawker_2.to_csv('hawker_NEW.csv',index = False)

npc = pd.read_csv("npc_geoloc.csv.csv")
npc1 = npc[['NPC','LATITUDE', 'LONGITUDE']]
map_npc = find_nearest(geo1,npc1)
map_npc1 = pd.DataFrame(map_npc)
map_npc2 = map_npc1.transpose()
map_npc2.to_csv('npc_NEW.csv',index = False)

ps = pd.read_csv("primaryschoolsg.csv", encoding='mac_roman')
ps1 = ps[['Name', 'Latitude','Longitude']]
map_ps = find_nearest(geo1,ps1)
map_ps1 = pd.DataFrame(map_ps)
map_ps2 = map_ps1.transpose()
map_ps2.to_csv('ps_NEW.csv',index = False)

ss = pd.read_csv("secsch_cleaned_1.csv", encoding='mac_roman')
ss1 = ss[['SCHNAME', 'latitude','longitude']]
map_ss = find_nearest(geo1,ss1)
map_ss1 = pd.DataFrame(map_ss)
map_ss2 = map_ss1.transpose()
map_ss2.to_csv('SS_NEW.csv',index = False)

cc = pd.read_csv("cc_geoloc.csv")
cc1 = cc[['CC', 'LATITUDE', 'LONGITUDE']]
map_cc = find_nearest(geo1,cc1)
map_cc1 = pd.DataFrame(map_cc)
map_cc2 = map_cc1.transpose()
map_cc2.to_csv('CC_NEW.csv',index = False)

# For Mrt - # find nearest train station to the flat
mrt = pd.read_csv("mrtsg.csv")
mrt1 = mrt[['STN_NAME', 'Latitude', 'Longitude']]
map_mrt = find_nearest(geo1,mrt1)
map_mrt1 = pd.DataFrame(map_mrt)
map_mrt2 = map_mrt1.transpose()
map_mrt2.to_csv('MRT_NEW.csv',index = False)
